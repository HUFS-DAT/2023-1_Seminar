# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np 
from pandas.api.types import CategoricalDtype
import seaborn as sns

from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
#Diamonds Prices2022
data = pd.read_csv('C:/Users/2001_/Desktop/고은서/2023-1/DAT/프로젝트/Diamonds Prices2022.csv')
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53943 non-null  float64
#  1   cut      53943 non-null  object
#  2   color    53943 non-null  object
#  3   clarity  53943 non-null  object
#  4   depth    53943 non-null  float64
#  5   table    53943 non-null  float64
#  6   price    53943 non-null  int64
#  7   x        53943 non-null  float64
#  8   y        53943 non-null  float64
#  9   z        53943 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
data['color']=np.where(data['color'] =='D', '6', data['color'])
data['color']=np.where(data['color'] =='E', '5', data['color'])
data['color']=np.where(data['color'] =='F', '4', data['color'])
data['color']=np.where(data['color'] =='G', '3', data['color'])
data['color']=np.where(data['color'] =='H', '2', data['color'])
data['color']=np.where(data['color'] =='I', '1', data['color'])
data['color']=np.where(data['color'] =='J', '0', data['color'])

# %%
data['cut']=np.where(data['cut'] =='Ideal', '4', data['cut'])
data['cut']=np.where(data['cut'] =='Premium', '3', data['cut'])
data['cut']=np.where(data['cut'] =='Very Good', '2', data['cut'])
data['cut']=np.where(data['cut'] =='Good', '1', data['cut'])
data['cut']=np.where(data['cut'] =='Fair', '0', data['cut'])

# %%
data['clarity']=np.where(data['clarity'] =='IF', '7', data['clarity'])
data['clarity']=np.where(data['clarity'] =='VVS1', '6', data['clarity'])
data['clarity']=np.where(data['clarity'] =='VVS2', '5', data['clarity'])
data['clarity']=np.where(data['clarity'] =='VS1', '4', data['clarity'])
data['clarity']=np.where(data['clarity'] =='VS2', '3', data['clarity'])
data['clarity']=np.where(data['clarity'] =='SI1', '2', data['clarity'])
data['clarity']=np.where(data['clarity'] =='SI2', '1', data['clarity'])
data['clarity']=np.where(data['clarity'] =='I1', '0', data['clarity'])

# %%
data['cut'] = data['cut'].astype('float64')
data['color'] = data['color'].astype('float64')
data['clarity'] = data['clarity'].astype('float64')

# %%
# convert cut, color, and clarity into ordered categorical types
data_category = {'cut': ['Fair','Good','Very Good','Premium','Ideal'],
                    'color': ['J', 'I', 'H', 'G', 'F', 'E', 'D'],
                    'clarity': ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']}

ordered_cut = pd.api.types.CategoricalDtype(ordered = True, categories = data_category['cut'])
data['cut'] = data['cut'].astype(ordered_cut)
ordered_color = pd.api.types.CategoricalDtype(ordered = True, categories = data_category['color'])
data['color'] = data['color'].astype(ordered_color)
ordered_clarity = pd.api.types.CategoricalDtype(ordered = True, categories = data_category['clarity'])
data['clarity'] = data['clarity'].astype(ordered_clarity)

# %%
import pandas as pd

data_category = {
    'cut': ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],
    'color': ['J', 'I', 'H', 'G', 'F', 'E', 'D'],
    'clarity': ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
}

data = pd.DataFrame({
    'cut': ['Fair', 'Good', 'Good', 'Very Good', 'Premium'],
    'color': ['H', 'J', 'E', 'G', 'F'],
    'clarity': ['SI2', 'VS1', 'SI1', 'VS2', 'IF']
})

ordered_cut = pd.api.types.CategoricalDtype(ordered=True, categories=data_category['cut'])
data['cut'] = data['cut'].astype(ordered_cut).cat.codes

ordered_color = pd.api.types.CategoricalDtype(ordered=True, categories=data_category['color'])
data['color'] = data['color'].astype(ordered_color).cat.codes

ordered_clarity = pd.api.types.CategoricalDtype(ordered=True, categories=data_category['clarity'])
data['clarity'] = data['clarity'].astype(ordered_clarity).cat.codes

print(data)
# Out:
#    cut  color  clarity
# 0    0      2        1
# 1    1      0        4
# 2    1      5        2
# 3    2      3        3
# 4    3      4        7

# %%
data.dtypes
# Out:
# carat      float64
# cut        float64
# color      float64
# clarity    float64
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
data.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean       0.797935      2.904084      3.405873      3.050980     61.749322
# std        0.473999      1.116576      1.701087      1.647103      1.432626
# min        0.200000      0.000000      0.000000      0.000000     43.000000
# 25%        0.400000      2.000000      2.000000      2.000000     61.000000
# 50%        0.700000      3.000000      3.000000      3.000000     61.800000
# 75%        1.040000      4.000000      5.000000      4.000000     62.500000
# max        5.010000      4.000000      6.000000      7.000000     79.000000
#
#               table         price             x             y             z
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean      57.457251   3932.734294      5.731158      5.734526      3.538730
# std        2.234549   3989.338447      1.121730      1.142103      0.705679
# min       43.000000    326.000000      0.000000      0.000000      0.000000
# 25%       56.000000    950.000000      4.710000      4.720000      2.910000
# 50%       57.000000   2401.000000      5.700000      5.710000      3.530000
# 75%       59.000000   5324.000000      6.540000      6.540000      4.040000
# max       95.000000  18823.000000     10.740000     58.900000     31.800000

# %%
plt.figure(figsize=(19, 12))

   
ax1 = plt.subplot(3, 3, 1)
sns.countplot(x=data['cut'].sort_values())
#plt.grid()

ax2 = plt.subplot(3, 3, 2)
sns.countplot(x=data['color'].sort_values())
#plt.grid()

ax3 = plt.subplot(3, 3, 3)
sns.countplot(x=data['clarity'].sort_values())
#plt.grid()
# Out:
# <Axes: xlabel='clarity', ylabel='count'>

# %%
plt.figure(figsize=(19, 12))
ax1 = plt.subplot(3, 3, 1)
plt.hist(data['cut'],bins=4)

plt.grid()

ax2 = plt.subplot(3, 3, 2)
plt.hist(data['color'],bins=4)

plt.grid()


ax3 = plt.subplot(3, 3, 3)
plt.hist(data['clarity'],bins=4)

plt.grid()

# %%
num_cols = data.select_dtypes('number')
i = 1
plt.figure(figsize=(19, 12))
for c in num_cols.columns:
    plt.subplot(3, 3, i)
    sns.boxplot(x=data[c])
    i+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 5
#       3 plt.figure(figsize=(19, 12))
#       4 for c in num_cols.columns:
# ----> 5     plt.subplot(3, 3, i)
#       6     sns.boxplot(x=data[c])
#       7     i+=1
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:1296, in subplot(*args, **kwargs)
#    1293 fig = gcf()
#    1295 # First, search for an existing subplot with a matching spec.
# -> 1296 key = SubplotSpec._from_subplot_args(fig, args)
#    1298 for ax in fig.axes:
#    1299     # if we found an Axes at the position sort out if we can re-use it
#    1300     if ax.get_subplotspec() == key:
#    1301         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:594, in SubplotSpec._from_subplot_args(figure, args)
#     592 else:
#     593     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 594         raise ValueError(
#     595             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     596             f"not {num!r}"
#     597         )
#     598     i = j = num
#     599 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 9, not 10

# %%
i = 1
plt.figure(figsize=(19, 16))
for c in data.columns:
    plt.subplot(4, 3, i)
    sns.scatterplot(x=data[c], y=data['price'])
    i+=1

# %%
#pairgrid = sns.pairplot(data)

sns.pairplot(data, diag_kind='kde')

# %%
data_corr = data.corr()
data_corr
# Out:
#             carat       cut     color   clarity     depth     table     price  \
# carat    1.000000 -0.134964 -0.291439 -0.352833  0.028234  0.181602  0.921591
# cut     -0.134964  1.000000  0.020506  0.189171 -0.218037 -0.433387 -0.053487
# color   -0.291439  0.020506  1.000000 -0.025646 -0.047316 -0.026457 -0.172520
# clarity -0.352833  0.189171 -0.025646  1.000000 -0.067355 -0.160328 -0.146791
# depth    0.028234 -0.218037 -0.047316 -0.067355  1.000000 -0.295798 -0.010630
# table    0.181602 -0.433387 -0.026457 -0.160328 -0.295798  1.000000  0.127118
# price    0.921591 -0.053487 -0.172520 -0.146791 -0.010630  0.127118  1.000000
# x        0.975093 -0.125564 -0.270281 -0.371996 -0.025289  0.195333  0.884433
# y        0.951721 -0.121461 -0.263579 -0.358417 -0.029340  0.183750  0.865419
# z        0.953387 -0.149320 -0.268226 -0.366946  0.094927  0.150915  0.861249
#
#                 x         y         z
# carat    0.975093  0.951721  0.953387
# cut     -0.125564 -0.121461 -0.149320
# color   -0.270281 -0.263579 -0.268226
# clarity -0.371996 -0.358417 -0.366946
# depth   -0.025289 -0.029340  0.094927
# table    0.195333  0.183750  0.150915
# price    0.884433  0.865419  0.861249
# x        1.000000  0.974701  0.970771
# y        0.974701  1.000000  0.952005
# z        0.970771  0.952005  1.000000

# %%
plt.matshow(data_corr)
#plt.matshow(df_corr, cmap='hot')
sns.heatmap(data.corr(),annot=True,cmap='YlGnBu',linewidth=0.01, annot_kws={'size': 6});
plt.xticks(range(len(data_corr.columns)), data_corr.columns)
plt.yticks(range(len(data_corr.index)), data_corr.index)
plt.title('Correlation Heatmap',fontsize=12,fontweight=5);
#plt.colorbar()

# %%
plt.figure(figsize=(30,30));
sns.heatmap(data.corr(),annot=True,cmap='RdBu',linewidth=0.01, annot_kws={'size': 18});
plt.title('Correlation Heatmap',fontsize=32,fontweight=5);

# %%
from sklearn.linear_model import LinearRegression # <> Classification
from sklearn import metrics

# %%
model = LinearRegression() #모델 설정

# %%
data.dtypes
# Out:
# carat      float64
# cut        float64
# color      float64
# clarity    float64
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
data.dtypes
# Out:
# carat      float64
# cut        float64
# color      float64
# clarity    float64
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
data
# Out:
#        carat  cut  color  clarity  depth  table  price     x     y     z
# 0       0.23  4.0    5.0      1.0   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  3.0    5.0      2.0   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23  1.0    5.0      4.0   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29  3.0    1.0      3.0   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31  1.0    0.0      1.0   63.3   58.0    335  4.34  4.35  2.75
# ...      ...  ...    ...      ...    ...    ...    ...   ...   ...   ...
# 53938   0.86  3.0    2.0      1.0   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75  4.0    6.0      1.0   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71  3.0    5.0      2.0   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71  3.0    4.0      2.0   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  2.0    5.0      3.0   60.5   59.0   2757  5.71  5.76  3.47
#
# [53943 rows x 10 columns]

# %%
X = data.drop('price', axis = 1, inplace=False)
y = data['price']

# %%
X.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z
# 0   0.23  4.0    5.0      1.0   61.5   55.0  3.95  3.98  2.43
# 1   0.21  3.0    5.0      2.0   59.8   61.0  3.89  3.84  2.31
# 2   0.23  1.0    5.0      4.0   56.9   65.0  4.05  4.07  2.31
# 3   0.29  3.0    1.0      3.0   62.4   58.0  4.20  4.23  2.63
# 4   0.31  1.0    0.0      1.0   63.3   58.0  4.34  4.35  2.75

# %%
data.describe().T
# Out:
#            count         mean          std    min     25%      50%      75%  \
# carat    53943.0     0.797935     0.473999    0.2    0.40     0.70     1.04
# cut      53943.0     2.904084     1.116576    0.0    2.00     3.00     4.00
# color    53943.0     3.405873     1.701087    0.0    2.00     3.00     5.00
# clarity  53943.0     3.050980     1.647103    0.0    2.00     3.00     4.00
# depth    53943.0    61.749322     1.432626   43.0   61.00    61.80    62.50
# table    53943.0    57.457251     2.234549   43.0   56.00    57.00    59.00
# price    53943.0  3932.734294  3989.338447  326.0  950.00  2401.00  5324.00
# x        53943.0     5.731158     1.121730    0.0    4.71     5.70     6.54
# y        53943.0     5.734526     1.142103    0.0    4.72     5.71     6.54
# z        53943.0     3.538730     0.705679    0.0    2.91     3.53     4.04
#
#               max
# carat        5.01
# cut          4.00
# color        6.00
# clarity      7.00
# depth       79.00
# table       95.00
# price    18823.00
# x           10.74
# y           58.90
# z           31.80

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)
print(X_train.shape)
print(X_test.shape)
# Out:
# (37760, 9)
# (16183, 9)

# %%
import numpy as np

model.fit(X, y)

y_pred = model.predict(X)

#예측값과 실제 데이터 간 오차 계산
rmse = np.sqrt(metrics.mean_squared_error(y_pred, y)) #mse에 루트씌운게 rmse
print('RMSE : ', rmse)
model.fit(X_train, y_train)
# Out:
# RMSE :  1216.5178597046054
# LinearRegression()

# %%
model.fit(X_train, y_train)

y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# %%
model.fit(X_train, y_train)

y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

rmse_test = np.sqrt(metrics.mean_squared_error(y_test_pred, y_test))
rmse_train = np.sqrt(metrics.mean_squared_error(y_train_pred, y_train))

# %%
print('RMSE test: ', rmse_test)
print('RMSE train:', rmse_train)
# Out:
# RMSE test:  1185.98204954148
# RMSE train: 1229.7575577777077

# %%
coef = pd.Series(data = model.coef_, index = X.columns)
#coef = pd.DataFrame(coef)
coef
# Out:
# carat      10513.614912
# cut          123.070627
# color        322.650844
# clarity      504.584283
# depth        -70.900545
# table        -23.809936
# x           -777.637617
# y             24.911232
# z             -8.858043
# dtype: float64

# %%
model.score(X_train, y_train)
# Out:
# 0.9059901902280291

# %%
model.score(X_test, y_test)
# Out:
# 0.909329603449591

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(X.values, ix) for ix in range(X.shape[1])]

# %%
i=0
for column in X.columns:
    if i < 11:
        print (column ,"--->",  vif[i])
        i = i+1
# Out:
# carat ---> 74.39631528741279
# cut ---> 8.864495309963468
# color ---> 5.5909656234603045
# clarity ---> 5.312947330187243
# depth ---> 569.3399020582802
# table ---> 546.8938261123219
# x ---> 1356.573399075948
# y ---> 531.8694344317353
# z ---> 562.8222790918203

# %%
X.shape[1]
# Out:
# 9
