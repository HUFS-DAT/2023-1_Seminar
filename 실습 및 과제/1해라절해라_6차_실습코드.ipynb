# %%
import pandas as pd
df=pd.read_csv('boston celtics.csv')
df

df[['Player','TRB','FG%','3P%','2P%','eFG%','FT%','AST','STL','BLK','TOV']]
df.rename(columns={'Player':'이름','TRB':'리바운드','FG%':'성공률','3P%':'3점슛','2P%':'2점슛','eFG%':'효율성','FT%':'자유투','AST':'어시스트','STL':'스틸','BLK':'방해','TOV':'실책'},inplace=True)
df[['이름','리바운드','성공률','3점슛','2점슛','효율성','자유투','어시스트','스틸','방해','실책']]
# Out:
#                    이름  리바운드    성공률    3점슛    2점슛    효율성    자유투  어시스트   스틸  \
# 0        Jayson Tatum   8.8  0.466  0.350  0.558  0.543  0.854   4.6  1.1
# 1        Jaylen Brown   6.9  0.491  0.335  0.576  0.550  0.765   3.5  1.1
# 2        Marcus Smart   3.1  0.415  0.336  0.519  0.511  0.746   6.3  1.5
# 3          Al Horford   6.2  0.476  0.446  0.539  0.627  0.714   3.0  0.5
# 4       Derrick White   3.6  0.462  0.381  0.548  0.560  0.875   3.9  0.7
# 5     Malcolm Brogdon   4.2  0.484  0.444  0.510  0.574  0.870   3.7  0.7
# 6      Grant Williams   4.6  0.454  0.395  0.546  0.575  0.770   1.7  0.5
# 7     Robert Williams   8.3  0.747  0.000  0.751  0.747  0.610   1.4  0.6
# 8        Mike Muscala   3.4  0.472  0.385  0.708  0.612  0.692   0.6  0.2
# 9          Sam Hauser   2.6  0.455  0.418  0.656  0.631  0.706   0.9  0.4
# 10      Blake Griffin   3.8  0.485  0.348  0.625  0.573  0.656   1.5  0.3
# 11   Payton Pritchard   1.8  0.412  0.364  0.495  0.527  0.750   1.3  0.3
# ...

# %%
df[['이름','성공률']][:5]
# Out:
#               이름    성공률
# 0   Jayson Tatum  0.466
# 1   Jaylen Brown  0.491
# 2   Marcus Smart  0.415
# 3     Al Horford  0.476
# 4  Derrick White  0.462

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = ['JaysonTatum', 'JaylenBrown', 'MarcusSmart', 'AIHorfod', 'DerrickWhite']
y = [0.466, 0.491, 0.451, 0.476, 0.462]
plt.plot(x, y)
plt.show()

# %%
print(plt.plot(x,y))

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x, y)
plt.title('FG%')
# Out:
# Text(0.5, 1.0, 'FG%')

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15 
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(x, y)
plt.title('성공률')
# Out:
# Text(0.5, 1.0, '성공률')

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot(x,y)
plt.xlabel('X축',color='purple')
plt.ylabel('Y축',color='#00aa00')
# Out:
# Text(0, 0.5, 'Y축')

# %%
plt.plot(x,y)
plt.xlabel('X축',color='red',loc='right')
plt.ylabel('Y축',color='#00aa00',loc='top')
# Out:
# Text(0, 1, 'Y축')

# %%
plt.plot(x,y,label='성공률')
plt.legend()

# %%
plt.plot(x,y,label='성공률')
plt.legend(loc='upper right')

# %%
plt.plot(x,y,label='성공률')
plt.legend(loc='lower right')

# %%
plt.plot(x, y, label='범례')
plt.legend(loc=(0.7, 0.8))

# %%
plt.plot(x,y, linewidth=2)
plt.plot(x,y, marker='o')

# %%
plt.plot(x,y,marker='o', markersize=10, markeredgecolor='g', markerfacecolor='yellow')

# %%
plt.plot(x,y,linestyle='-.')

# %%
plt.plot(x,y,'yo--')

# %%
plt.plot(x,y, marker='o',ms=10, mec='blue', alpha=0.2)

# %%
plt.figure(figsize=(8, 4))
plt.plot(x,y)

# %%
plt.figure(figsize=(10,5),dpi=150) 
plt.plot(x,y)

# %%
plt.figure(facecolor='gray')
plt.plot(x,y)

# %%
plt.plot(x,y)

plt.savefig('graph.png',dpi=100)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,marker='o')

for idx, txt in enumerate(y):
    plt.text(x[idx], y[idx]+0.001, txt, ha='center', color='blue')

# %%
df[['이름','성공률','효율성','2점슛']][:5]
# Out:
#               이름    성공률    효율성    2점슛
# 0   Jayson Tatum  0.466  0.543  0.558
# 1   Jaylen Brown  0.491  0.550  0.576
# 2   Marcus Smart  0.415  0.511  0.519
# 3     Al Horford  0.476  0.627  0.539
# 4  Derrick White  0.462  0.560  0.548

# %%
이름 = ['JaysonTatum', 'JaylenBrown', 'MarcusSmart', 'AIHorfod', 'DerrickWhite']
성공률 = [0.466, 0.491, 0.451, 0.476, 0.462]
효율성 = [0.543,0.550,0.511,0.627,0.560]
_2점슛 = [0.558,0.576,0.519,0.539,0.548]
plt.plot(이름, 성공률)
plt.plot(이름, 효율성)
plt.plot(이름, _2점슛)

# %%
plt.plot(이름, 성공률, label='성공률')
plt.plot(이름, 효율성, label='효율성', marker='o', ls='--')
plt.plot(이름, _2점슛, label='2점슛', marker='s', ls='-.')

plt.legend()

# %%
plt.plot(이름, 성공률, label='성공률')
plt.plot(이름, 효율성, label='효율성', marker='o', ls='--')
plt.plot(이름, _2점슛, label='2점슛', marker='s', ls='-.')

plt.legend(ncol=3)

# %%
df[['이름','리바운드']][:5]
# Out:
#               이름  리바운드
# 0   Jayson Tatum   8.8
# 1   Jaylen Brown   6.9
# 2   Marcus Smart   3.1
# 3     Al Horford   6.2
# 4  Derrick White   3.6

# %%
labels = ['JaysonTatum', 'JaylenBrown', 'MarcusSmart', 'AIHorfod', 'DerrickWhite']
values = [8.8,6.9,3.1,6.2,3.6]
plt.bar(labels, values)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['JaysonTatum', 'JaylenBrown', 'MarcusSmart', 'AIHorfod', 'DerrickWhite']
values = [8.8,6.9,3.1,6.2,3.6]
colors = ['r','y','orange','green','blue']
plt.bar(labels, values,color=colors,alpha=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['JaysonTatum', 'JaylenBrown', 'MarcusSmart', 'AIHorfod', 'DerrickWhite']
values = [8.8,6.9,3.1,6.2,3.6]
colors = ['r','y','orange','green','blue']
plt.bar(labels, values,color=colors,alpha=0.5)
plt.ylim(1.0,9.0)
# Out:
# (1.0, 9.0)

# %%
plt.bar(labels,values,color=colors,alpha=0.5)
plt.xticks(rotation=40)
plt.yticks(rotation=30)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 2.0, '2'),
#   Text(0, 4.0, '4'),
#   Text(0, 6.0, '6'),
#   Text(0, 8.0, '8'),
#   Text(0, 10.0, '10')])

# %%
labels = ['JaysonTatum', 'JaylenBrown', 'MarcusSmart', 'AIHorfod', 'DerrickWhite']
values = [8.8,6.9,3.1,6.2,3.6]
colors = ['r','y','orange','green','blue']
plt.barh(labels, values,color=colors,alpha=0.5)
plt.xlim(1.0,9.0)
# Out:
# (1.0, 9.0)

# %%
labels = ['JaysonTatum', 'JaylenBrown', 'MarcusSmart', 'AIHorfod', 'DerrickWhite']
values = [8.8,6.9,3.1,6.2,3.6]
colors = ['r','y','orange','green','blue']
plt.bar(labels, values,color=colors,alpha=0.5)
plt.ylim(1.0,9.0)
for idx,rect in enumerate(bar):
    plt.text(idx, rect.get_height()-0.35, values[idx], ha='center')
plt.xticks(rotation=40)
plt.yticks(rotation=30)
plt.show()
